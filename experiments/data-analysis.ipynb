# %%
# Imports
import pandas as pd
import numpy as np
import scipy as sp

filename = "exp-data.csv"

# %%
df = pd.DataFrame.from_csv(filename)
groups = df.groupby(["data", "struct"])

# %%
print "Min values:"
df.groupby(["data", "struct"]).min()
# Out:
# Min values:
#                    K     # nodes     # edges  dsk time (s)  sort time (s)  \
# data    struct
# chrom14 hyper     56  1624442199  1651477269       3480.14      10065.171
#         standard  56  1624442199  1651477269       3480.14       8854.179
# ecoli   hyper     28   528581516   548545502       1662.83       1143.612
#         standard  28   528581516   548545502       1662.83        995.531
#
#                   build time (s)   W (MB)   L (MB)  LCS (MB)  # queries  \
# data    struct
# chrom14 hyper           1127.508  385.678  28.2605   413.939      20000
#         standard         305.773  385.678  28.2605       NaN      20000
# ecoli   hyper            334.325  142.878  19.7740   257.483      20000
#         standard         113.101  142.878  19.7740       NaN      20000
#
#                         ...          shorter1 mean (ns)  shorter2 (ns) mean  \
# data    struct          ...
# chrom14 hyper           ...                     46579.5             42681.5
# ...

# %%
print "Mean values:"
df.groupby(["data", "struct"]).mean()
# Out:
# Mean values:
#                    K     # nodes     # edges  dsk time (s)  sort time (s)  \
# data    struct
# chrom14 hyper     56  1624442199  1651477269   3527.253333   11017.234667
#         standard  56  1624442199  1651477269   3527.253333    8883.766000
# ecoli   hyper     28   528581516   548545502   1765.633333    1152.524333
#         standard  28   528581516   548545502   1765.633333    1020.859333
#
#                   build time (s)   W (MB)   L (MB)  LCS (MB)  # queries  \
# data    struct
# chrom14 hyper        1146.602667  385.678  28.2605   413.939      20000
#         standard      318.174333  385.678  28.2605       NaN      20000
# ecoli   hyper         344.220333  142.878  19.7740   257.483      20000
#         standard      115.785000  142.878  19.7740       NaN      20000
#
#                         ...          shorter1 mean (ns)  shorter2 (ns) mean  \
# data    struct          ...
# chrom14 hyper           ...                60329.833333        47252.400000
# ...

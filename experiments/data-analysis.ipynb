# %%
# Imports
import pandas as pd
import numpy as np
import scipy as sp

pd.set_option('display.max_seq_items', 200)

filename = "exp-data.csv"

# %%
df = pd.DataFrame.from_csv(filename)
groups = df.groupby(["data", "struct"])

# %%
print "Min values:"
groups.describe()
# Out:
# Min values:
#                            # edges     # nodes  # queries   K   L (MB)    LCS (MB)      W (MB)  backward mean time (ns)  build time (s)  dsk time (s)      ...        longer2 mean (ns)  \
# data    struct                                                                                                                                             ...
# chrom14 hyper    count           3           3          3   3   3.0000    3.000000    3.000000                 3.000000        3.000000      3.000000      ...                 3.000000
#                  mean   1651477269  1624442199      20000  56  28.2605  413.939000  385.678000            303214.333333     1146.602667   3527.253333      ...            203376.000000
#                  std             0           0          0   0   0.0000    0.000000    0.000000             83742.290877       18.606870     42.337213      ...             57729.765494
# ...

# %%
print "Mean values:"
groups.mean()
# Out:
# Mean values:
#                    K     # nodes     # edges  dsk time (s)  sort time (s)  build time (s)   W (MB)   L (MB)  LCS (MB)  # queries        ...          shorter1 mean (ns)  shorter2 (ns) mean  \
# data    struct                                                                                                                          ...
# chrom14 hyper     56  1624442199  1651477269   3527.253333   11017.234667     1146.602667  385.678  28.2605   413.939      20000        ...                60329.833333        47252.400000
#         standard  56  1624442199  1651477269   3527.253333    8883.766000      318.174333  385.678  28.2605       NaN      20000        ...                         NaN                 NaN
# ecoli   hyper     28   528581516   548545502   1765.633333    1152.524333      344.220333  142.878  19.7740   257.483      20000        ...                48882.400000        36705.433333
# ...
